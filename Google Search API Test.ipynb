# %%
# Put your personal API key here
apiKey = 'AIzaSyCIplXpNgYZ2IS44ZYyEi-hXRu1gzl9I58'

# Search engine ID
cseKey = "23c1c70a203ac4852"

# %%
import pandas as pd
import requests
import numpy as np
from math import ceil
from tqdm import tqdm

from googleapiclient.discovery import build

# %%
search_query = "markiplier social media"

# %%
google_search = build("customsearch", "v1", developerKey=apiKey).cse()

# %%
print(google_search)

# %%
results = google_search.list(
    q=search_query,
    cx=cseKey
).execute()

# %%
type(results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['kind', 'url', 'queries', 'context', 'searchInformation', 'items'])

# %%
results.get("items")
# Out:
# [{'kind': 'customsearch#result',
#   'title': 'Markiplier (@markiplier) • Instagram photos and videos',
#   'htmlTitle': '<b>Markiplier</b> (@<b>markiplier</b>) • <b>Instagram</b> photos and videos',
#   'link': 'https://www.instagram.com/markiplier/?hl=en',
#   'displayLink': 'www.instagram.com',
#   'snippet': '12M Followers, 90 Following, 1104 Posts - See Instagram photos and videos from Markiplier (@markiplier)',
#   'htmlSnippet': '12M Followers, 90 Following, 1104 Posts - See <b>Instagram</b> photos and videos from <b>Markiplier</b> (@<b>markiplier</b>)',
#   'formattedUrl': 'https://www.instagram.com/markiplier/?hl=en',
#   'htmlFormattedUrl': 'https://www.instagram.com/<b>markiplier</b>/?hl=en',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTRIJoh1DBpqfU3-lW5P8d-YLwzGKVPXo7trQlZrQhYqGWKVkQvFSqw',
#      'width': '100',
#      'height': '100'}],
#    'xfn': [{}],
# ...

# %%
type(results.get("items"))
# Out:
# list

# %%
results.get("items")[0]
# Out:
# {'kind': 'customsearch#result',
#  'title': 'Markiplier (@markiplier) • Instagram photos and videos',
#  'htmlTitle': '<b>Markiplier</b> (@<b>markiplier</b>) • <b>Instagram</b> photos and videos',
#  'link': 'https://www.instagram.com/markiplier/?hl=en',
#  'displayLink': 'www.instagram.com',
#  'snippet': '12M Followers, 90 Following, 1104 Posts - See Instagram photos and videos from Markiplier (@markiplier)',
#  'htmlSnippet': '12M Followers, 90 Following, 1104 Posts - See <b>Instagram</b> photos and videos from <b>Markiplier</b> (@<b>markiplier</b>)',
#  'formattedUrl': 'https://www.instagram.com/markiplier/?hl=en',
#  'htmlFormattedUrl': 'https://www.instagram.com/<b>markiplier</b>/?hl=en',
#  'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTRIJoh1DBpqfU3-lW5P8d-YLwzGKVPXo7trQlZrQhYqGWKVkQvFSqw',
#     'width': '100',
#     'height': '100'}],
#   'xfn': [{}],
# ...

# %%
type(results.get("items")[0])
# Out:
# dict

# %%
len(results.get("items"))
# Out:
# 10

# %%
results.get("items")[0].keys()
# Out:
# dict_keys(['kind', 'title', 'htmlTitle', 'link', 'displayLink', 'snippet', 'htmlSnippet', 'formattedUrl', 'htmlFormattedUrl', 'pagemap'])

# %%
item_1 = results.get("items")[0]

# %%
item_1.get("title")
# Out:
# 'Markiplier (@markiplier) • Instagram photos and videos'

# %%
item_1.get("link")
# Out:
# 'https://www.instagram.com/markiplier/?hl=en'

# %%
item_1.get("snippet")
# Out:
# '12M Followers, 90 Following, 1104 Posts - See Instagram photos and videos from Markiplier (@markiplier)'
