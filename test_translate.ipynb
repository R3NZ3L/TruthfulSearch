# %%
import translators as ts
from langdetect import detect

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd
import numpy as np
import YT_scraper
import csv

# %%
comments = pd.read_csv("./datasets/covid_philippines/covid_philippines_comments.csv")
comments
# Out:
#       Unnamed: 0     video_id  \
# 0              0  aLZ85hb4wjE
# 1              1  aLZ85hb4wjE
# 2              2  aLZ85hb4wjE
# 3              3  aLZ85hb4wjE
# 4              4  aLZ85hb4wjE
# ...          ...          ...
# 1472        1472  VpyMHOAJ2qc
# 1473        1473  VpyMHOAJ2qc
# 1474        1474  VpyMHOAJ2qc
# 1475        1475  VpyMHOAJ2qc
# 1476        1476  VpyMHOAJ2qc
#
#                                                 comment
# 0                        Loved the calmness of Manilla.
# 1     The lockdown makes the city look like a place ...
# 2                                       India also same
# 3     After this pandemic I think every country shou...
# 4              manila looks beautifull with less people
# ...                                                 ...
# 1472  Kung mate test lng lahat ng may covid symptoms...
# 1473  Naisip nyo ba na yung 1 month Community Quaran...
# 1474  Marami pong nagsasabi na ang china ang may kas...
# ...

# %%
comments["comment"][1472]
# Out:
# 'Kung mate test lng lahat ng may covid symptoms higit pa yan sa 230. Kasi d2 samin ospital pinapa uwi lng pero hindi tinetest at may sintomas na. Pero pag mga pulpolitiko kahit wala sintomas test agad.'

# %%
ts.translate_text(comments["comment"][1472],translator='google')
# Out:
# 'If all the tests have a test of covid symptoms more than 230. because the hospital is home to return home but it is not a symptom and a symptom. But pulpolitics even without symptoms test immediately.'

# %%
translated_comment = comments.copy()

# %%
translated_comment
# Out:
#       Unnamed: 0     video_id  \
# 0              0  aLZ85hb4wjE
# 1              1  aLZ85hb4wjE
# 2              2  aLZ85hb4wjE
# 3              3  aLZ85hb4wjE
# 4              4  aLZ85hb4wjE
# ...          ...          ...
# 1472        1472  VpyMHOAJ2qc
# 1473        1473  VpyMHOAJ2qc
# 1474        1474  VpyMHOAJ2qc
# 1475        1475  VpyMHOAJ2qc
# 1476        1476  VpyMHOAJ2qc
#
#                                                 comment
# 0                        Loved the calmness of Manilla.
# 1     The lockdown makes the city look like a place ...
# 2                                       India also same
# 3     After this pandemic I think every country shou...
# 4              manila looks beautifull with less people
# ...                                                 ...
# 1472  Kung mate test lng lahat ng may covid symptoms...
# 1473  Naisip nyo ba na yung 1 month Community Quaran...
# 1474  Marami pong nagsasabi na ang china ang may kas...
# ...

# %%
comments["comment"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1472    False
# 1473    False
# 1474    False
# 1475    False
# 1476    False
# Name: comment, Length: 1477, dtype: bool

# %%
#for i in range(len(translated_comment["comment"])):
for i in range(len(translated_comment["comment"])): ##currently errors if more than this; need to restart kernel if irurun again
    if translated_comment["comment"][i] != None:
        try:
            lang = detect(translated_comment["comment"][i])
            if lang !='en':
                translated_comment["comment"][i] = ts.translate_text(translated_comment["comment"][i],'google',to_language = 'en')
        except:
           # print("cannot detect language for " + "'"+translated_comment[i]+ "'")
            continue
# Out:
# C:\Users\Melanie\AppData\Local\Temp\ipykernel_14200\1598135630.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   translated_comment["comment"][i] = ts.translate_text(translated_comment["comment"][i],'google',to_language = 'en')
# C:\Users\Melanie\AppData\Local\Temp\ipykernel_14200\1598135630.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   translated_comment["comment"][i] = ts.translate_text(translated_comment["comment"][i],'google',to_language = 'en')
# C:\Users\Melanie\AppData\Local\Temp\ipykernel_14200\1598135630.py:7: SettingWithCopyWarning:
# ...

# %%
translated_comment["comment"]
# Out:
# 0                          Loved the calmness of Manilla.
# 1       The lockdown makes the city look like a place ...
# 2                                         India also same
# 3       After this pandemic I think every country shou...
# 4                manila looks beautifull with less people
#                               ...
# 1472    If all the tests have a test of covid symptoms...
# 1473    Did you think that the 1 month community quara...
# 1474    Many say that China is the culprit but they al...
# 1475                                                  Omg
# 1476                                                  Any
# Name: comment, Length: 1477, dtype: object

# %%
comments["comment"]
# Out:
# 0                          Loved the calmness of Manilla.
# 1       The lockdown makes the city look like a place ...
# 2                                         India also same
# 3       After this pandemic I think every country shou...
# 4                manila looks beautifull with less people
#                               ...
# 1472    Kung mate test lng lahat ng may covid symptoms...
# 1473    Naisip nyo ba na yung 1 month Community Quaran...
# 1474    Marami pong nagsasabi na ang china ang may kas...
# 1475                                                  Omg
# 1476                                                 Hala
# Name: comment, Length: 1477, dtype: object
